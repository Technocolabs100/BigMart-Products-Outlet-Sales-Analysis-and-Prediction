# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from pylab import rcParams

# %%
data = pd.read_csv("C:\\Users\\Dell\\Desktop\\Internship\\Train.csv")
data
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0              FDA15        9.300          Low Fat         0.016047
# 1              DRC01        5.920          Regular         0.019278
# 2              FDN15       17.500          Low Fat         0.016760
# 3              FDX07       19.200          Regular         0.000000
# 4              NCD19        8.930          Low Fat         0.000000
# ...              ...          ...              ...              ...
# 8518           FDF22        6.865          Low Fat         0.056783
# 8519           FDS36        8.380          Regular         0.046982
# 8520           NCJ29       10.600          Low Fat         0.035186
# 8521           FDN46        7.210          Regular         0.145221
# 8522           DRG01       14.800          Low Fat         0.044878
#
#                   Item_Type  Item_MRP Outlet_Identifier  \
# 0                     Dairy  249.8092            OUT049
# ...

# %%
data.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15         9.30          Low Fat         0.016047
# 1           DRC01         5.92          Regular         0.019278
# 2           FDN15        17.50          Low Fat         0.016760
# 3           FDX07        19.20          Regular         0.000000
# 4           NCD19         8.93          Low Fat         0.000000
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# 3  Fruits and Vegetables  182.0950            OUT010
# 4              Household   53.8614            OUT013
#
#    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                       1999      Medium               Tier 1
# 1                       2009      Medium               Tier 3
# ...

# %%
data.describe()
# Out:
#        Item_Weight  Item_Visibility     Item_MRP  Outlet_Establishment_Year  \
# count  7060.000000      8523.000000  8523.000000                8523.000000
# mean     12.857645         0.066132   140.992782                1997.831867
# std       4.643456         0.051598    62.275067                   8.371760
# min       4.555000         0.000000    31.290000                1985.000000
# 25%       8.773750         0.026989    93.826500                1987.000000
# 50%      12.600000         0.053931   143.012800                1999.000000
# 75%      16.850000         0.094585   185.643700                2004.000000
# max      21.350000         0.328391   266.888400                2009.000000
#
#        Item_Outlet_Sales
# count        8523.000000
# mean         2181.288914
# std          1706.499616
# min            33.290000
# 25%           834.247400
# 50%          1794.331000
# 75%          3101.296400
# max         13086.964800

# %%
data.columns
# Out:
# Index(['Item_Identifier', 'Item_Weight', 'Item_Fat_Content', 'Item_Visibility',
#        'Item_Type', 'Item_MRP', 'Outlet_Identifier',
#        'Outlet_Establishment_Year', 'Outlet_Size', 'Outlet_Location_Type',
#        'Outlet_Type', 'Item_Outlet_Sales'],
#       dtype='object')

# %% [raw]
# Data Cleaning

# %%
missing_values_count= data.isnull().sum()
missing_values_count
# Out:
# Item_Identifier                 0
# Item_Weight                  1463
# Item_Fat_Content                0
# Item_Visibility                 0
# Item_Type                       0
# Item_MRP                        0
# Outlet_Identifier               0
# Outlet_Establishment_Year       0
# Outlet_Size                  2410
# Outlet_Location_Type            0
# Outlet_Type                     0
# Item_Outlet_Sales               0
# dtype: int64

# %%
data.shape
# Out:
# (8523, 12)

# %%
data[data.duplicated()].shape
# Out:
# (0, 12)

# %%
import seaborn as sns
cols = data.columns 
colours = ['#000099', '#ffff00'] # specify the colours - yellow is missing. blue is not missing.
sns.heatmap(data[cols].isnull(),cmap=sns.color_palette(colours))
# Out:
# <AxesSubplot:>

# %%
data[data.isnull().any(axis=1)].head()
# Out:
#    Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 3            FDX07         19.2          Regular         0.000000
# 7            FDP10          NaN          Low Fat         0.127470
# 8            FDH17         16.2          Regular         0.016687
# 9            FDU28         19.2          Regular         0.094450
# 18           DRI11          NaN          Low Fat         0.034238
#
#                 Item_Type  Item_MRP Outlet_Identifier  \
# 3   Fruits and Vegetables  182.0950            OUT010
# 7             Snack Foods  107.7622            OUT027
# 8            Frozen Foods   96.9726            OUT045
# 9            Frozen Foods  187.8214            OUT017
# 18            Hard Drinks  113.2834            OUT027
#
#     Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 3                        1998         NaN               Tier 3
# 7                        1985      Medium               Tier 3
# ...

# %%
data.isnull().sum()
# Out:
# Item_Identifier                 0
# Item_Weight                  1463
# Item_Fat_Content                0
# Item_Visibility                 0
# Item_Type                       0
# Item_MRP                        0
# Outlet_Identifier               0
# Outlet_Establishment_Year       0
# Outlet_Size                  2410
# Outlet_Location_Type            0
# Outlet_Type                     0
# Item_Outlet_Sales               0
# dtype: int64

# %%
mean =data['Item_Weight'].mean()
print(mean)
# Out:
# 12.857645184136183

# %%
data1=data['Item_Weight'].fillna(mean)
data1
# Out:
# 0        9.300
# 1        5.920
# 2       17.500
# 3       19.200
# 4        8.930
#          ...
# 8518     6.865
# 8519     8.380
# 8520    10.600
# 8521     7.210
# 8522    14.800
# Name: Item_Weight, Length: 8523, dtype: float64

# %%
obj_columns=data[['Outlet_Size']]

# %%
obj_columns.isnull().sum()
# Out:
# Outlet_Size    2410
# dtype: int64

# %%
data3=obj_columns.fillna(obj_columns.mode().iloc[0])

# %%
data3.isnull().sum()
# Out:
# Outlet_Size    0
# dtype: int64

# %%
data.shape
# Out:
# (8523, 12)

# %%
data3.shape
# Out:
# (8523, 1)

# %%
data2=pd.concat([data1,data3],axis=1)
data2
# Out:
#       Item_Weight Outlet_Size
# 0           9.300      Medium
# 1           5.920      Medium
# 2          17.500      Medium
# 3          19.200      Medium
# 4           8.930        High
# ...           ...         ...
# 8518        6.865        High
# 8519        8.380      Medium
# 8520       10.600       Small
# 8521        7.210      Medium
# 8522       14.800       Small
#
# [8523 rows x 2 columns]

# %%
data2.isnull().sum()
# Out:
# Item_Weight    0
# Outlet_Size    0
# dtype: int64

# %%
data4=data.drop(['Item_Weight','Outlet_Size'],axis=1)

# %%
data4
# Out:
#      Item_Identifier Item_Fat_Content  Item_Visibility              Item_Type  \
# 0              FDA15          Low Fat         0.016047                  Dairy
# 1              DRC01          Regular         0.019278            Soft Drinks
# 2              FDN15          Low Fat         0.016760                   Meat
# 3              FDX07          Regular         0.000000  Fruits and Vegetables
# 4              NCD19          Low Fat         0.000000              Household
# ...              ...              ...              ...                    ...
# 8518           FDF22          Low Fat         0.056783            Snack Foods
# 8519           FDS36          Regular         0.046982           Baking Goods
# 8520           NCJ29          Low Fat         0.035186     Health and Hygiene
# 8521           FDN46          Regular         0.145221            Snack Foods
# 8522           DRG01          Low Fat         0.044878            Soft Drinks
#
# ...

# %%
data5=pd.concat([data4,data2],axis=1)

# %%
data5
# Out:
#      Item_Identifier Item_Fat_Content  Item_Visibility              Item_Type  \
# 0              FDA15          Low Fat         0.016047                  Dairy
# 1              DRC01          Regular         0.019278            Soft Drinks
# 2              FDN15          Low Fat         0.016760                   Meat
# 3              FDX07          Regular         0.000000  Fruits and Vegetables
# 4              NCD19          Low Fat         0.000000              Household
# ...              ...              ...              ...                    ...
# 8518           FDF22          Low Fat         0.056783            Snack Foods
# 8519           FDS36          Regular         0.046982           Baking Goods
# 8520           NCJ29          Low Fat         0.035186     Health and Hygiene
# 8521           FDN46          Regular         0.145221            Snack Foods
# 8522           DRG01          Low Fat         0.044878            Soft Drinks
#
# ...

# %%
data5['Item_Outlet_Sales'].hist()
# Out:
# <AxesSubplot:>

# %%
data5.boxplot(column=['Item_Outlet_Sales'])
# Out:
# <AxesSubplot:>

# %%
data5['Item_Outlet_Sales'].describe()
# Out:
# count     8523.000000
# mean      2181.288914
# std       1706.499616
# min         33.290000
# 25%        834.247400
# 50%       1794.331000
# 75%       3101.296400
# max      13086.964800
# Name: Item_Outlet_Sales, dtype: float64

# %%
data5
# Out:
#      Item_Identifier Item_Fat_Content  Item_Visibility              Item_Type  \
# 0              FDA15          Low Fat         0.016047                  Dairy
# 1              DRC01          Regular         0.019278            Soft Drinks
# 2              FDN15          Low Fat         0.016760                   Meat
# 3              FDX07          Regular         0.000000  Fruits and Vegetables
# 4              NCD19          Low Fat         0.000000              Household
# ...              ...              ...              ...                    ...
# 8518           FDF22          Low Fat         0.056783            Snack Foods
# 8519           FDS36          Regular         0.046982           Baking Goods
# 8520           NCJ29          Low Fat         0.035186     Health and Hygiene
# 8521           FDN46          Regular         0.145221            Snack Foods
# 8522           DRG01          Low Fat         0.044878            Soft Drinks
#
# ...

# %% [raw]
# Scatter plot and correlation analysis

# %%
sns.pairplot(data5)

# %%
data5.corr()
# Out:
#                            Item_Visibility  Item_MRP  \
# Item_Visibility                   1.000000 -0.001315
# Item_MRP                         -0.001315  1.000000
# Outlet_Establishment_Year        -0.074834  0.005020
# Item_Outlet_Sales                -0.128625  0.567574
# Item_Weight                      -0.012049  0.024756
#
#                            Outlet_Establishment_Year  Item_Outlet_Sales  \
# Item_Visibility                            -0.074834          -0.128625
# Item_MRP                                    0.005020           0.567574
# Outlet_Establishment_Year                   1.000000          -0.049135
# Item_Outlet_Sales                          -0.049135           1.000000
# Item_Weight                                -0.008301           0.011550
#
#                            Item_Weight
# Item_Visibility              -0.012049
# Item_MRP                      0.024756
# Outlet_Establishment_Year    -0.008301
# Item_Outlet_Sales             0.011550
# ...

# %%
data6=pd.get_dummies(data5,columns=['Outlet_Size','Item_Identifier','Item_Fat_Content','Outlet_Location_Type','Outlet_Identifier','Item_Type','Outlet_Type'])
data6
# Out:
#       Item_Visibility  Item_MRP  Outlet_Establishment_Year  Item_Outlet_Sales  \
# 0            0.016047  249.8092                       1999          3735.1380
# 1            0.019278   48.2692                       2009           443.4228
# 2            0.016760  141.6180                       1999          2097.2700
# 3            0.000000  182.0950                       1998           732.3800
# 4            0.000000   53.8614                       1987           994.7052
# ...               ...       ...                        ...                ...
# 8518         0.056783  214.5218                       1987          2778.3834
# 8519         0.046982  108.1570                       2002           549.2850
# 8520         0.035186   85.1224                       2004          1193.1136
# 8521         0.145221  103.1332                       2009          1845.5976
# 8522         0.044878   75.4670                       1997           765.6700
#
# ...

# %% [raw]
# Normalization of data

# %%
from numpy import set_printoptions
from sklearn.preprocessing import MinMaxScaler

# %%
data6.values
# Out:
# array([[1.60473010e-02, 2.49809200e+02, 1.99900000e+03, ...,
#         1.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#        [1.92782160e-02, 4.82692000e+01, 2.00900000e+03, ...,
#         0.00000000e+00, 1.00000000e+00, 0.00000000e+00],
#        [1.67600750e-02, 1.41618000e+02, 1.99900000e+03, ...,
#         1.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#        ...,
#        [3.51862710e-02, 8.51224000e+01, 2.00400000e+03, ...,
#         1.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#        [1.45220646e-01, 1.03133200e+02, 2.00900000e+03, ...,
#         0.00000000e+00, 1.00000000e+00, 0.00000000e+00],
#        [4.48782800e-02, 7.54670000e+01, 1.99700000e+03, ...,
#         1.00000000e+00, 0.00000000e+00, 0.00000000e+00]])

# %%
array = data6.values

scaler = MinMaxScaler(feature_range=(0,1))
rescaledX = scaler.fit_transform(array[:,0:5])

#transformed data
set_printoptions(precision=2)
print(rescaledX[0:5,:])
# Out:
# [[0.05 0.93 0.58 0.28 0.28]
#  [0.06 0.07 1.   0.03 0.08]
#  [0.05 0.47 0.58 0.16 0.77]
#  [0.   0.64 0.54 0.05 0.87]
#  [0.   0.1  0.08 0.07 0.26]]

# %%
#Standardize data (0 mean, 1 stdev)
from sklearn.preprocessing import StandardScaler

# %%
array = data6.values
scaler = StandardScaler().fit(array)
rescaledX = scaler.transform(array)

# summarize transformed data
set_printoptions(precision=2)
print(rescaledX[0:5,:])
# Out:
# [[-0.97  1.75  0.14 ...  0.73 -0.35 -0.35]
#  [-0.91 -1.49  1.33 ... -1.38  2.86 -0.35]
#  [-0.96  0.01  0.14 ...  0.73 -0.35 -0.35]
#  [-1.28  0.66  0.02 ... -1.38 -0.35 -0.35]
#  [-1.28 -1.4  -1.29 ...  0.73 -0.35 -0.35]]

# %% [raw]
# Exploratory Data Analysis

# %%
import matplotlib.pyplot as plt
import seaborn as sns
plt.figure(figsize=(10,10))
sns.heatmap(data5.corr(),cbar=True,annot=True,cmap='Blues')
# Out:
# <AxesSubplot:>

# %% [raw]
# Item_MRP and Item_Outlet_Sales are positively correlated with each other.

# %%
p = data5.hist(figsize = (15,15))

# %%
sns.boxplot(data5['Item_MRP'])
# Out:
# C:\Users\Dell\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Item_MRP'>

# %%
sns.boxplot(data5['Outlet_Establishment_Year'])
# Out:
# C:\Users\Dell\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Outlet_Establishment_Year'>

# %%
sns.boxplot(data5['Item_Outlet_Sales'])
# Out:
# C:\Users\Dell\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Item_Outlet_Sales'>

# %%
data5.plot(kind='scatter',x='Item_Outlet_Sales',y='Item_MRP')
# Out:
# <AxesSubplot:xlabel='Item_Outlet_Sales', ylabel='Item_MRP'>

# %%
import statsmodels.api as sm
import numpy as np

# %%
X=data["Item_MRP"]
Y=data["Item_Outlet_Sales"]

# %%
X=sm.add_constant(X)
model=sm.OLS(Y,X)
results=model.fit()

# %%
results.params
# Out:
# const      -11.575143
# Item_MRP    15.553024
# dtype: float64

# %%
print(results.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:      Item_Outlet_Sales   R-squared:                       0.322
# Model:                            OLS   Adj. R-squared:                  0.322
# Method:                 Least Squares   F-statistic:                     4049.
# Date:                Fri, 25 Nov 2022   Prob (F-statistic):               0.00
# Time:                        11:11:40   Log-Likelihood:                -73866.
# No. Observations:                8523   AIC:                         1.477e+05
# Df Residuals:                    8521   BIC:                         1.478e+05
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        -11.5751     37.671     -0.307      0.759     -85.420      62.270
# ...

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
regressor = RandomForestRegressor(n_estimators = 100, random_state = 0)

# %%
regressor.fit(x, y)

# %%
Y_pred = regressor.predict(np.array([6.5]).reshape(1, 1))
